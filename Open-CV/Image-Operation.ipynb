# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load Image

print(cv2.__version__)
# Out:
# 4.10.0

# %%
# Read Image
Image = cv2.imread("pic.jpg")

# %%
#  Display Image using IMREAD command

# plt.imshow(cv2.cvtColor(Image , cv2.COLOR_BGR2GRAY))
# plt.imshow(cv2.cvtColor(Image , cv2.COLOR_BGR2HSV))
# plt.imshow(cv2.cvtColor(Image , cv2.COLOR_BGR2LUV))
plt.imshow(cv2.cvtColor(Image , cv2.COLOR_BGR2RGB))
plt.show()

# %%
def imshow(Image, title=""):
    cv2.imshow(title, cv2.cvtColor(Image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

imshow("The quick brown fox jumps over the lazy dog", Image)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[5], line 6
#       3     plt.title(title)
#       4     plt.show()
# ----> 6 imshow("The quick brown fox jumps over the lazy dog", Image)
#
# Cell In[5], line 2, in imshow(Image, title)
#       1 def imshow(Image, title=""):
# ----> 2     cv2.imshow(title, cv2.cvtColor(Image, cv2.COLOR_BGR2RGB))
#       3     plt.title(title)
#       4     plt.show()
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'

# %%
cv2.imwrite("outputimage.jpg" , Image)
# Out:
# True

# %%
print(Image.shape)
# Out:
# (1752, 1314, 3)

# %%
def imshow( title= "Images " , Image = None , size = 5):
    w , h  = Image.shape[0] , Image.shape[1]
    aspect_ratio = w / h
    fig = plt.figure(figsize = (size * aspect_ratio , size))
    plt.imshow(cv2.cvtColor(Image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
Image =cv2.imread("Pic.jpg")
imshow("Waseem Nazeer",Image)

# %%
Image.shape
B , G, R = cv2.split(Image)
print(B.shape)
print(R.shape)
print(G.shape)
# Out:
# (1752, 1314)
# (1752, 1314)
# (1752, 1314)

# %%
# Image Different Colors Creation
zeros = np.zeros(Image.shape[:2] , dtype= "uint8")

imshow("Red" , cv2.merge([zeros , zeros , R]))
imshow("Green" , cv2.merge([zeros , G, zeros]))
imshow("Red" , cv2.merge([B, zeros , zeros]))

# %%
# Merged 
merged = cv2.merge([B , R , G ])
merged = cv2.merge([R , G , B ])
merged1 = cv2.merge([ B, G , R ])
merged2 = cv2.merge([ B + 100 , G - 10 , R + 50 ])
imshow("Merged Picture" , merged1)
imshow("Merged  with Color Addition Picture" , merged2)

# %%
hsvpic =  cv2.imread("Pic.jpg")
hsv_image = cv2.cvtColor(hsvpic , cv2.COLOR_RGB2HSV)
imshow("HSV-Picture" , hsvpic)
imshow("Hue" , hsvpic[ : , : , 0] )
imshow("Saturation" , hsvpic[ :, :, 1] )
imshow("Value" , hsvpic[:, :, 2] )

# %%
# Create a Black Image by Numpy and OPENCV
image = np.zeros((512 , 512 , 3) , np.uint8)
image_grey = np.zeros((512 , 512 ) , np.uint8)

imshow("Black Canvas RGB  Color" , image)
imshow("Black Canvas Grey Scale" , image_grey)

# %%
# Drawing a Black Line over Grey scale and RGB Image
cv2.line(image , (0,0) , (512 , 511) ,(255 , 117 ,0) , 5 )
imshow("Black Canvas picture over a line" , image)

# %%
image = np.zeros((512 , 512 , 3) , np.uint8)
cv2.rectangle(image , (100,100) , (300 , 250 ) ,(120  , 250 ,127) , 10 )
imshow("Black Canvas picture with a Rectangle" , image)

# %%
image = np.zeros((512 , 512 , 3) , np.uint8)
cv2.circle(image , (300 , 350 ) , 100 , (250  , 250 ,127) , -1 )
imshow("Black Canvas picture with a Circle" , image)

# %%
image = np.zeros((512 , 512 , 3) , np.uint8)
pts = np.array([[10,50] , [400,50] , [100 , 290] , [500 , 500 ]] , np.int32)
pts = pts.reshape((-1,1 , 2))
cv2.polylines(image , [pts] , True , (0,0,255) , 3)

imshow("Black Canvas picture with a Polgon" , image)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Create a blank black image (1000x1000 pixels)
image = np.zeros((1000, 1000, 3), np.uint8)

# Define the text to display
outstring = "Hello Mohsin"

# Add text to the image with OpenCV
cv2.putText(image, outstring, (155, 290), cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 200, 400), 4)


plt.imshow(image)
plt.title("Image with Text")
plt.axis("off")  
plt.show()

# %%
# Transformation using OPENCV
# Translation is Shifting the Position of an Image
# we do use cv2.wrapAffine to implement translation
